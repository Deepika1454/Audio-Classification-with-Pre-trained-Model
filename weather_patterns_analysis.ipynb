# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika1454/Audio-Classification-with-Pre-trained-Model/blob/main/weather_patterns_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Date': pd.date_range(start='2020-01-01', periods=365, freq='D'),
    'Temperature': [20 + (x % 30) + (x % 7) for x in range(365)],
    'Rainfall': [0 if x % 10 != 0 else (x % 20) for x in range(365)]
}

weather_df = pd.DataFrame(data)

# %%
print(weather_df.head())
# Out:
#         Date  Temperature  Rainfall
# 0 2020-01-01           20         0
# 1 2020-01-02           22         0
# 2 2020-01-03           24         0
# 3 2020-01-04           26         0
# 4 2020-01-05           28         0

# %% [markdown]
# Line Plot for Temperature:

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(data=weather_df, x='Date', y='Temperature', color='orange')
plt.title('Daily Temperature Over One Year')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# Bar Plot for Rainfall

# %%
plt.figure(figsize=(14, 6))
sns.barplot(data=weather_df, x='Date', y='Rainfall', color='blue')
plt.title('Daily Rainfall Over One Year')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.xticks(rotation=45)
plt.grid()
plt.show()
